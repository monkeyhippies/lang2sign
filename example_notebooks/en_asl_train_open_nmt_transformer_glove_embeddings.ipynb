# %%
# !pip install git+https://github.com/monkeyhippies/OpenNMT-tf.git@bug

# %%
# !cd lang2sign && git pull origin open-nmt-small && rm -rf models/
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# Unpacking objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 4 (delta 0), pack-reused 0
# From https://github.com/monkeyhippies/lang2sign
#  * branch            open-nmt-small -> FETCH_HEAD
#    f0a4087..dd4044e  open-nmt-small -> origin/open-nmt-small
# Updating f0a4087..dd4044e
# Fast-forward
#  configs/open-nmt/models/transformer_shared_embedding.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !rm -rf lang2sign
# !git clone https://github.com/monkeyhippies/lang2sign.git
# !cd lang2sign && git checkout open-nmt-10
# Out:
# Cloning into 'lang2sign'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 486 (delta 131), reused 172 (delta 72), pack-reused 252
# Receiving objects: 100% (486/486), 330.34 KiB | 1.16 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# Branch 'open-nmt-10' set up to track remote branch 'open-nmt-10' from 'origin'.
# Switched to a new branch 'open-nmt-10'

# %%
# !cd lang2sign && make data pretrained-embeddings preprocess
# Out:
# ./scripts/download_en_asl_gloss_data.sh
# --2019-09-24 21:34:22--  https://raw.githubusercontent.com/monkeyhippies/speech2signs-2017-nmt/master/ASLG-PC12/train.tgz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3765908 (3.6M) [application/octet-stream]
# Saving to: ‘data/raw/lang2gloss/enasl/train.tgz’
#
# train.tgz           100%[===================>]   3.59M  --.-KB/s    in 0.05s
#
# 2019-09-24 21:34:23 (67.8 MB/s) - ‘data/raw/lang2gloss/enasl/train.tgz’ saved [3765908/3765908]
#
# train/
# train/ENG-ASL_Train_0.046.asl
# train/ENG-ASL_Train_0.046.en
# --2019-09-24 21:34:23--  https://raw.githubusercontent.com/monkeyhippies/speech2signs-2017-nmt/master/ASLG-PC12/dev.tgz
# ...

# %%
# !cat lang2sign/pretrained-embeddings/glove.6B.300d.txt.trimmed.vocab | wc -l
# Out:
# 7074

# %%
# !cd lang2sign && onmt-main train_and_eval --model configs/open-nmt/models/transformer_shared_embedding.py --config configs/open-nmt/transformer-glove-embeddings.yaml
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/decoders/rnn_decoder.py:435: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/adafactor.py:32: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/multistep_adam.py:36: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !cd lang2sign && cat data/preprocessed/lang2gloss/enasl/test/ENG-ASL_Test_0.046.en | tail -n 3 > test.txt

# %%
# !cd lang2sign && cat data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.en | tail -n 10 > test.txt

# %%
# !cat lang2sign/test.txt
# Out:
# the sitting closed at 16.30
# mobiliation of the european globalisation adjustment fund lear from spain
# corrections to votes and voting intentions see minutes

# %%
# !cd lang2sign && onmt-main eval \
    --config configs/open-nmt/transformer-glove-embeddings.yaml \
    --checkpoint_path models/transformer-glove/model.ckpt-70000
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/decoders/rnn_decoder.py:435: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/adafactor.py:32: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/multistep_adam.py:36: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !cd lang2sign && onmt-main infer \
    --model configs/open-nmt/models/transformer_shared_embedding.py \
    --config configs/open-nmt/transformer-glove-embeddings.yaml \
    --features_file test.txt \
    --predictions_file predictions.out2 \
    --checkpoint_path  models/transformer-glove/model.ckpt-8407
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/decoders/rnn_decoder.py:435: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/adafactor.py:32: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/optimizers/multistep_adam.py:36: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/opennmt/bin/main.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !cat lang2sign/predictions.out2
# Out:
# desc - close at <unk>
# european globalisation adjustment european globalisation adjustment fund from spain
# correction to vote and vote intention see

# %%
# !mv lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.en_ORIGINAL lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.en
# !mv lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.asl_ORIGINAL lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.asl

# %%
rm lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.en lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.asl

# %%
# !cat lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.asl | wc -l
# Out:
# 1

# %%
# !bash -c 'for run in {1..10000}; do echo "opening of the sitting" >> lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.en; done'
# !bash -c 'for run in {1..10000}; do echo "open sit" >> lang2sign/data/preprocessed/lang2gloss/enasl/train/ENG-ASL_Train_0.046.asl; done'

# %%
models/transformer-glove/model.ckpt
